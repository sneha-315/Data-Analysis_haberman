# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\KIIT0001\Desktop\New folder\Day 2\Assignment\haberman.csv")
print(data)
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %%
print(data.shape)
# Out:
# (306, 4)

# %%
print(data.columns)
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
data['age'].value_counts()
# Out:
# age
# 52    14
# 54    13
# 50    12
# 47    11
# 53    11
# 43    11
# 57    11
# 49    10
# 65    10
# 55    10
# 38    10
# 41    10
# 42     9
# 45     9
# 61     9
# 59     8
# 63     8
# 56     7
# 58     7
# 62     7
# 48     7
# 46     7
# 44     7
# 70     7
# 34     7
# 51     6
# 67     6
# 39     6
# 37     6
# 60     6
# 66     5
# 64     5
# 69     4
# 72     4
# 30     3
# 40     3
# 31     2
# 68     2
# 36     2
# 35     2
# 33     2
# 73     2
# 74     2
# 71     1
# 75     1
# 76     1
# 77     1
# 78     1
# 83     1
# Name: count, dtype: int64

# %%
data.plot(kind='scatter',x='age',y='year')
plt.show()

# %%
data.plot(kind='scatter',x='year',y='nodes')
plt.show()

# %%
data.plot(kind='scatter',x='year',y='status')
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="age") \
   .map(plt.scatter, "year", "nodes") \
   .add_legend()
plt.show()

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(data, hue="age")
plt.show()

# %%
sns.FacetGrid(data, hue="age") \
   .map(sns.histplot, "year") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(data, hue="age") \
   .map(sns.histplot, "nodes") \
   .add_legend()
plt.show()

# %%
sns.FacetGrid(data, hue="age") \
   .map(sns.histplot, "status") \
   .add_legend()
plt.show()

# %%
counts, bin_edges = np.histogram(data['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(data['nodes'], bins=20, 
                                 density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);

plt.show();
# Out:
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
counts, bin_edges = np.histogram(data['nodes'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,label='PDF')
plt.plot(bin_edges[1:], cdf,label='CDF')
plt.xlabel('nodes')
plt.ylabel('probabilities')
plt.legend()


plt.show()
# Out:
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
sns.boxplot(x='age',y='nodes', data=data)
plt.savefig('plot.png')
plt.show()

# %%
sns.boxplot(x='age',y='year', data=data)
plt.savefig('plot.png')
plt.show()

# %%
sns.boxplot(x='age',y='status', data=data)
plt.savefig('plot.png')
plt.show()

# %%
sns.boxplot(x='year',y='nodes', data=data)
plt.savefig('plot.png')
plt.show()

# %%
sns.boxplot(x='year',y='status', data=data)
plt.savefig('plot.png')
plt.show()

# %%
sns.violinplot(x="year", y="status", data=data)
plt.show()

# %%
sns.violinplot(x="year", y="nodes", data=data)
plt.show()

# %%
sns.violinplot(x="status", y="nodes", data=data)
plt.show()
